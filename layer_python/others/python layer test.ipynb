# %%
import sys
import numpy as np
sys.path.insert(0,'../../caffe-windows/Build/x64/Debug/pycaffe/')
import caffe

# %%
from skimage import io

# %%
io.imread('./download.png')[100,55,0]
# Out:
# 200

# %%
solver = caffe.SGDSolver('./solver.prototxt')

# %%
x = solver.net.forward()
# Out:
# WARNING:root:0.12299990654

# %%
print solver.net.blobs['data'].data.shape
print solver.net.blobs['label'].data.shape
print solver.net.blobs['bbox'].data.shape
# Out:
# (1L, 3L, 356L, 293L)
# (1L,)
# (1L, 5L)

# %%
x = solver.net.forward()
solver.net.blobs['data'].data.shape
# Out:
# WARNING:root:0.121999979019
# (1L, 3L, 356L, 293L)

# %%
from skimage import io, transform
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im = io.imread('../dataset/fashion-data/images/0/n02854926/n02854926_10038_0.jpg')

# %%
print im.shape
# Out:
# (266L, 120L, 3L)

# %%
im = transform.resize(im, (100,100,3) )
plt.imshow(im)

# %%
def func(x):
    return x**2

# %%
a = [1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3,1,2,3]

# %%
from multiprocessing.dummy import Pool as ThreadPool

# %%
pool = ThreadPool(8)
b = pool.map(func, a)
pool.close()
pool.join()

# %%
b
# Out:
# [1, 4, 9, 1, 4, 9, 1, 4, 9, 1, 4, 9, 1, 4, 9, 1, 4, 9, 1, 4, 9]

# %%
np.random.permutation(np.arange(10))
# Out:
# array([5, 3, 0, 9, 6, 8, 4, 1, 2, 7])

# %%
a = [1,2,3,0]

# %%
np.logical_not(a)
# Out:
# array([False, False, False,  True], dtype=bool)

# %%
solver.net.layers[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a961f0788590> in <module>()
# ----> 1 solver.net.layers[0].setup()
#
# TypeError: setup() takes exactly 3 arguments (1 given)

# %%
a = np.array([(1,2),(3,4)])

# %%
a.shape
# Out:
# (2L, 2L)

# %%
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a - 1
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
a - [1,2]
# Out:
# array([[0, 0],
#        [2, 2]])

# %%
a = np.random.randn(3,2,2)

# %%
a[0]
# Out:
# array([[-0.84027336,  2.22196919],
#        [ 1.58668614,  1.17283011]])

# %%
a - np.array([10,100,1000]).reshape(3,1,1)
# Out:
# array([[[  -10.84027336,    -7.77803081],
#         [   -8.41331386,    -8.82716989]],
#
#        [[  -98.89627447,   -99.96426937],
#         [  -99.83956002,  -100.0042078 ]],
#
#        [[-1001.05421137, -1001.31819624],
#         [-1001.42714175,  -999.00807128]]])
